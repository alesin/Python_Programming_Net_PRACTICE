# %% [markdown]
# ### From website https://pythonprogramming.net/data-analysis-python-pandas-tutorial-introduction/

# %% [markdown]
# import scripts

# %%
import pandas as pd
import datetime
#import pandas.io.data as web
#from pandas_datareader import data, web

import matplotlib.pyplot as plt
from matplotlib import style

#style used on website
style.use('fivethirtyeight')
#style used in YouTube video
#style.use('ggplot')

# %%
web_stats = {'Day':[1,2,3,4,5,6],
             'Visitors':[43,34,65,56,29,76],
             'Bounce Rate':[65,67,78,65,45,52]}

df = pd.DataFrame(web_stats)

# %%
print(df.head())
# Out:
#    Bounce Rate  Day  Visitors
# 0           65    1        43
# 1           67    2        34
# 2           78    3        65
# 3           65    4        56
# 4           45    5        29

# %%
print(df.tail())
# Out:
#    Bounce Rate  Day  Visitors
# 1           67    2        34
# 2           78    3        65
# 3           65    4        56
# 4           45    5        29
# 5           52    6        76

# %%
print(df.tail(2))
# Out:
#    Bounce Rate  Day  Visitors
# 4           45    5        29
# 5           52    6        76

# %%
#strongly recommend against altering df inplace... sloppy!
#df = df.set_index('Day')
#alternative code for same purpose...
#df.set_index('Day', inplace=True)

#creates new data frame
df_indexed_by_day = df.set_index('Day')
print(df_indexed_by_day.head())
# Out:
#      Bounce Rate  Visitors
# Day
# 1             65        43
# 2             67        34
# 3             78        65
# 4             65        56
# 5             45        29

# %%
df['Visitors'].plot()
plt.show()

# %%
df.plot()
plt.show()

# %% [markdown]
# Reference multiple columns at a time.
# The code for this is a list of column headers, held by brackets, within brackets from the dataframe.

# %%
print(df[['Visitors','Bounce Rate']])
# Out:
#    Visitors  Bounce Rate
# 0        43           65
# 1        34           67
# 2        65           78
# 3        56           65
# 4        29           45
# 5        76           52
